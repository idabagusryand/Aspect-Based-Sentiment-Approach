# %%
# 1
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2
# install library/package
# !pip install Sastrawi #untuk menjalankan stemming
# !pip install fasttext #untuk mentraining embedding fasttext
# !pip install gensim #untuk mentraining embedding fasttext
# !pip install iterative-stratification #untuk menggunakan multilabel stratified k-fold
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 2.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (75.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.26.4)
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4296186 sha256=c3d5417fdb7349a7042314b2d05e0941e38462e1d63a51792a5ae9214766ac15
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-2.13.6
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.17.0)
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.9-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (3.5.0)
# Downloading iterative_stratification-0.1.9-py3-none-any.whl (8.5 kB)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.9

# %%
# 3
#import library/package
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt
import Sastrawi
import codecs
import numpy as np
import shutil
import fasttext
import keras
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from gensim.corpora import WikiCorpus
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from tensorflow.keras import optimizers
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, GlobalMaxPooling1D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import EarlyStopping
from tqdm import tqdm
from gensim.models import FastText
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Flatten
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import StratifiedKFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
# plt.style.use('bmh')

# %%
#check data
df = pd.read_csv("/content/drive/MyDrive/TA/data/Sirkuit_Mandalika_Final.csv")
df
# Out:
#                                               full_text    aspek sentimen
# 0     Coba jalan-jalan di Mandalika sekitar sirkuit....  ekonomi  negatif
# 1     @detikcom pak sirkuit mandalika kapan di sindi...  ekonomi  negatif
# 2     @HeangKadrun @nepriadi74 @geloraco Ah bpk sdh ...  ekonomi  negatif
# 3     lawak bgt gue pikir pas denger isu tubatu ke m...  ekonomi  negatif
# 4     Selesaikan 30 Lap pada Hari Pertama di Mandali...  ekonomi  negatif
# ...                                                 ...      ...      ...
# 3417  Setelah balapan motogp di mandalika nama Indon...  politik  positif
# 3418  Kesan para pebalap #MotoGP kepada Presiden Jok...  politik  positif
# 3419  Presiden Jokowi optimistis #MotoGP mampu mempe...  politik  positif
# 3420  MotoGP berterima kasih atas sambutan hangat In...  politik  positif
# 3421  Acara parade rider MotoGP di Jakarta termasuk ...  politik  positif
#
# [3422 rows x 3 columns]

# %% [markdown]
# **1. Cleaning Data**

# %%
#melihat jumlah data
df.shape
# Out:
# (3422, 3)

# %%
#fungsi untuk membersihkan data
def cleaning(text):
  text = re.sub(r'@[A-Za-z0-9_]+', '', text) #membersihkan mention
  text = re.sub(r'#\w+', '', text) #membersihkan hastag
  text = re.sub(r'RT[\s]+', '', text) #membersihkan retweet
  text = re.sub(r'https?://\S+', '', text) #membersihkan url

  text = re.sub(r'[^A-Za-z0-9 ]', '', text) #membersihkan karakter selain A-Z, a-z, 0-9, spasi
  text = re.sub(r'\s+', ' ', text).strip() #membersihkan spasi yang berlebihan

  return text

df['full_text'] = df['full_text'].apply(cleaning)
df.head()
# Out:
#                                            full_text    aspek sentimen
# 0  Coba jalanjalan di Mandalika sekitar sirkuit I...  ekonomi  negatif
# 1  pak sirkuit mandalika kapan di sindir pak raky...  ekonomi  negatif
# 2  Ah bpk sdh pikun x hasil di depan mata nampak ...  ekonomi  negatif
# 3  lawak bgt gue pikir pas denger isu tubatu ke m...  ekonomi  negatif
# 4  Selesaikan 30 Lap pada Hari Pertama di Mandali...  ekonomi  negatif

# %%
#mengganti huruf menjadi huruf kecil
df['full_text'] = df['full_text'].str.lower()
df.head()
# Out:
#                                            full_text    aspek sentimen
# 0  coba jalanjalan di mandalika sekitar sirkuit i...  ekonomi  negatif
# 1  pak sirkuit mandalika kapan di sindir pak raky...  ekonomi  negatif
# 2  ah bpk sdh pikun x hasil di depan mata nampak ...  ekonomi  negatif
# 3  lawak bgt gue pikir pas denger isu tubatu ke m...  ekonomi  negatif
# 4  selesaikan 30 lap pada hari pertama di mandali...  ekonomi  negatif

# %% [markdown]
# **2. Preprocessing**

# %%
#normalisasi

norm = {" tsk ": " tidak "," tdk ": " tidak ", " sdh ": " sudah ", " yg ": " yang ",
        " blm ": " belum ", " gk ": " tidak ", " bgt ": " banget ", " tak ": " tidak ",
        " mmg ": " memang ", " dgn ": " dengan ", " utk ": " untuk ", " tp ": " tapi ",
        " spt ": " seperti ", "skrg ": " sekarang ", " ngk ": " tidak ", " jg ": " juga ",
        " kmrn ": " kemarin ", " wkt ": " waktu ", " trs ": " terus ", " lg ": " lagi ", " mrk ": " mereka ",
        " bpk ": " bapak ", " sdh ": " sudah ", " bkln ": " bakalan ", " pndptan ": " pendapatan ",
        " bgmn ": " bagaimana ", " gue ": " saya ", " gt ": " gitu ", " gw ": " saya ",
        " dah ": " sudah ", " x ": " kali ", " jls ": " jelas ", " msh ": " masih ",
        " utang ": " hutang ", " sgl ": " segala ", " gak ": " tidak ", " anjeng ": " anjing ",
        " better ": " lebih baik ", " mo ": " mau ", " geblek ": " goblok ", "kek": "kayak", "slh": "salah", "yak": "ya",
        "drpd": "daripada", "bekum": "belum", "paenonton": "penonton", "becua": "becus", "pertadingan": "pertandingan"}

def normalisasi(str_text):
  for i in norm:
    str_text = str_text.replace(i, norm[i])
  return str_text

df['full_text'] = df['full_text'].apply(lambda x: normalisasi(x))
df.head()
# Out:
#                                            full_text    aspek sentimen
# 0  coba jalanjalan di mandalika sekitar sirkuit i...  ekonomi  negatif
# 1  pak sirkuit mandalika kapan di sindir pak raky...  ekonomi  negatif
# 2  ah bapak sudah pikun kali hasil di depan mata ...  ekonomi  negatif
# 3  lawak banget saya pikir pas denger isu tubatu ...  ekonomi  negatif
# 4  selesaikan 30 lap pada hari pertama di mandali...  ekonomi  negatif

# %%
#stopwords #meghapus kata yang tidak memiliki arti

stop_words = StopWordRemoverFactory().get_stop_words()

new_array = ArrayDictionary(stop_words)
stop_words_remover_new = StopWordRemover(new_array)

def stopwords(str_text):
  str_text = stop_words_remover_new.remove(str_text)
  return str_text

df['full_text'] = df['full_text'].apply(lambda x: stopwords(x))
df.head()
# Out:
#                                            full_text    aspek sentimen
# 0  coba jalanjalan mandalika sirkuit kan lombok b...  ekonomi  negatif
# 1  pak sirkuit mandalika kapan sindir pak rakyat ...  ekonomi  negatif
# 2  ah bapak pikun kali hasil depan mata nampak ti...  ekonomi  negatif
# 3  lawak banget pikir pas denger isu tubatu manda...  ekonomi  negatif
# 4  selesaikan 30 lap hari pertama mandalika mario...  ekonomi  negatif

# %%
#tokenize

tokenized = df['full_text'].apply(lambda x: x.split())
tokenized.head()
# Out:
# 0    [coba, jalanjalan, mandalika, sirkuit, kan, lo...
# 1    [pak, sirkuit, mandalika, kapan, sindir, pak, ...
# 2    [ah, bapak, pikun, kali, hasil, depan, mata, n...
# 3    [lawak, banget, pikir, pas, denger, isu, tubat...
# 4    [selesaikan, 30, lap, hari, pertama, mandalika...
# Name: full_text, dtype: object

# %%
#stemming

def stemming(text_cleaning):
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()
  do = []
  for w in text_cleaning:
    dt = stemmer.stem(w)
    do.append(dt)
  d_clean = []
  d_clean = " ".join(do)
  return d_clean

tokenized = tokenized.apply(stemming )

# %%
# simpan data stemming di drive
tokenized.to_csv("/content/drive/MyDrive/TA/data/preprocessing/data_stemming.csv", index=False)

# %%
# gabung data yang sudah di preprocessing dengan data yang bersisi kolom aspek & sentimen
df1 = pd.read_csv("/content/drive/MyDrive/TA/data/preprocessing/data_stemming.csv", encoding='latin-1')
df2 = pd.read_csv("/content/drive/MyDrive/TA/data/aspek&sentimen.csv", encoding='latin-1')
joined_df = df1.join(df2, how='inner')
joined_df
# Out:
#                                               full_text    aspek sentimen
# 0     coba jalanjalan mandalika sirkuit kan lombok b...  ekonomi  negatif
# 1     pak sirkuit mandalika kapan sindir pak rakyat ...  ekonomi  negatif
# 2     ah bapak pikun kali hasil depan mata nampak ti...  ekonomi  negatif
# 3     lawak banget pikir pas denger isu tubatu manda...  ekonomi  negatif
# 4     selesai 30 lap hari pertama mandalika mario ku...  ekonomi  negatif
# ...                                                 ...      ...      ...
# 3417  balap motogp mandalika nama indonesia makin ke...  politik  positif
# 3418  kesan balap presiden jokowi sangat senang seka...  politik  positif
# 3419  presiden jokowi optimistis mampu kuat branding...  politik  positif
# 3420  motogp terima kasih atas sambut hangat indones...  politik  positif
# 3421  acara parade rider motogp jakarta masuk jamu p...  politik  positif
#
# [3422 rows x 3 columns]

# %%
# simpan data ke Gdrive
joined_df.to_csv("/content/drive/MyDrive/TA/data/data_ready.csv", index=False)

# %% [markdown]
# **3. Persiapan Klasifikasi**

# %%
# membuat model word embedding FastText
# load dataset artikel wikipedia ID

dataset = WikiCorpus("/content/drive/MyDrive/TA/embeddings/idwiki-latest-pages-articles.xml.bz2", dictionary={})

# %%
# mengolah dataset agar sesuai format yang bisa diproses oleh package fasttext
with open("wiki-id-formatted.txt", 'w', encoding="utf8") as output:
     counter = 0
     for text in dataset.get_texts():
         output.write(' '.join(text)+"\n")
         counter = counter + 1
         if counter > 150000: # Hanya mengambil 150,000 artikel pertama
             break

# %%
# proses pelatihan model
model = fasttext.train_unsupervised('wiki-id-formatted.txt', model='skipgram')

# %%
# simpan model ke GDrive
model.save_model("trained_model_id.bin")
shutil.copy2('trained_model_id.bin', '/content/drive/MyDrive/TA/embeddings/trained_model_id.bin')
# Out:
# '/content/drive/MyDrive/TA/embeddings/trained_model_id.bin'

# %%
# 4
# prepare fasttext model
fasttext_model = FastText.load_fasttext_format ("/content/drive/MyDrive/TA/embeddings/trained_model_id.bin")
embedding_dim = fasttext_model.vector_size
# Out:
# <ipython-input-4-fd0604efda13>:3: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   fasttext_model = FastText.load_fasttext_format ("/content/drive/MyDrive/TA/embeddings/trained_model_id.bin")

# %%
print("circuit" in fasttext_model.wv.key_to_index) # mengecek apakah ada kata di kamus
print(fasttext_model.wv.most_similar("circuit")) # mencari kata terdekat dari kata
# Out:
# True
# [('circuits', 0.8938945531845093), ('circuito', 0.8873134851455688), ('sirkuit', 0.8266257047653198), ('autodrome', 0.803618311882019), ('racingcircuits', 0.7942016124725342), ('urcuit', 0.76032954454422), ('autodrom', 0.7565967440605164), ('autodromo', 0.7455797791481018), ('silverstone', 0.721988320350647), ('eprix', 0.7215248942375183)]

# %%
# 5
# tokenisasi dan padding
data = pd.read_csv("/content/drive/MyDrive/TA/data/data_ready.csv")
max_words = 10000
max_len = 100
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(data['full_text'])
sequences = tokenizer.texts_to_sequences(data['full_text'])
X_pad = pad_sequences(sequences, maxlen=max_len)

# %%
# 6
# embedding matrix
embedding_matrix = np.zeros((max_words, embedding_dim))

# Loop melalui setiap kata dalam word_index tokenizer
word_index = tokenizer.word_index
for word, i in word_index.items():
    if i < max_words:
        if word in fasttext_model.wv:
            # Ambil vektor embedding untuk kata dari model FastText
            embedding_vector = fasttext_model.wv[word]
            embedding_matrix[i] = embedding_vector
        else:
            # Jika kata tidak ditemukan, cari kata terdekatnya
            try:
                similar_word = fasttext_model.wv.most_similar(word, topn=1)[0][0]  # Ambil kata terdekat pertama
                embedding_vector = fasttext_model.wv[similar_word]
                embedding_matrix[i] = embedding_vector
            except KeyError:
                # Jika kata terdekat juga tidak ditemukan, biarkan vektor nol
                pass

# %%
# 7
# Prepare label
y_aspek = pd.get_dummies(data['aspek'])
y_sentimen = pd.get_dummies(data['sentimen'])
y_multilabel = np.hstack([y_aspek.values, y_sentimen.values])  # Gabungkan label menjadi satu array agar dapat diproses pada multilabel stratified k-fold

# %%
X_pad
# Out:
# array([[   0,    0,    0, ...,  554, 1905,  166],
#        [   0,    0,    0, ...,   59, 1119,  263],
#        [   0,    0,    0, ...,  803,  200,  119],
#        ...,
#        [   0,    0,    0, ...,   10,   32,    1],
#        [   0,    0,    0, ...,  254,  700, 3372],
#        [   0,    0,    0, ...,  205,  342,  235]], dtype=int32)

# %%
X_pad.shape
# Out:
# (3422, 100)

# %%
y_aspek
# Out:
#       ekonomi  politik
# 0        True    False
# 1        True    False
# 2        True    False
# 3        True    False
# 4        True    False
# ...       ...      ...
# 3417    False     True
# 3418    False     True
# 3419    False     True
# 3420    False     True
# 3421    False     True
#
# [3422 rows x 2 columns]

# %%
y_sentimen
# Out:
#       negatif  netral  positif
# 0        True   False    False
# 1        True   False    False
# 2        True   False    False
# 3        True   False    False
# 4        True   False    False
# ...       ...     ...      ...
# 3417    False   False     True
# 3418    False   False     True
# 3419    False   False     True
# 3420    False   False     True
# 3421    False   False     True
#
# [3422 rows x 3 columns]

# %%
y_multilabel
# Out:
# array([[ True, False,  True, False, False],
#        [ True, False,  True, False, False],
#        [ True, False,  True, False, False],
#        ...,
#        [False,  True, False, False,  True],
#        [False,  True, False, False,  True],
#        [False,  True, False, False,  True]])

# %%
# Multilabel Stratified K-Fold pada data training
mskf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# List untuk menyimpan hasil evaluasi setiap fold
fold_results = []

for fold, (train_idx, test_idx) in enumerate(mskf.split(X_pad, y_multilabel)):
    print(f"Fold {fold + 1}")

    # bagi data training dan test
    X_train, X_test = X_pad[train_idx], X_pad[test_idx] #x
    y_train, y_test = y_multilabel[train_idx], y_multilabel[test_idx] #y

    # buat data testing akhir
    X_validation, X_testing, y_validation, y_testing = train_test_split(X_test, y_test, test_size=0.5, stratify=y_test)

    # Pisahkan y menjadi aspek dan sentimen
    y_train_aspek, y_train_sentimen = y_train[:, :y_aspek.shape[1]], y_train[:, y_aspek.shape[1]:]
    y_validation_aspek, y_validation_sentimen = y_validation[:, :y_aspek.shape[1]], y_validation[:, y_aspek.shape[1]:]
    y_testing_aspek, y_testing_sentimen = y_testing[:, :y_aspek.shape[1]], y_testing[:, y_aspek.shape[1]:]

    count_aspek_train = np.sum(y_train_aspek, axis=0)
    count_sentimen_train = np.sum(y_train_sentimen, axis=0)
    print("Count X train: ", X_train.shape[0])
    print("Count Aspect train: ", count_aspek_train)
    print("Count Sentimen train: ", count_sentimen_train)
    count_aspek_val = np.sum(y_validation_aspek, axis=0)
    count_sentimen_val = np.sum(y_validation_sentimen, axis=0)
    print("Count X validation: ", X_validation.shape[0])
    print("Count Aspect Validation: ", count_aspek_val)
    print("Count Sentimen Validation: ", count_sentimen_val)
    count_aspek_test = np.sum(y_testing_aspek, axis=0)
    count_sentimen_test = np.sum(y_testing_sentimen, axis=0)
    print("Count X test: ", X_testing.shape[0])
    print("Count Aspect Test: ", count_aspek_test)
    print("Count Sentimen Test: ", count_sentimen_test)
    print("")
# Out:
# Fold 1
# Count X train:  2737
# Count Aspect train:  [1638 1099]
# Count Sentimen train:  [ 996 1215  526]
# Count X validation:  342
# Count Aspect Validation:  [205 137]
# Count Sentimen Validation:  [125 151  66]
# Count X test:  343
# Count Aspect Test:  [205 138]
# Count Sentimen Test:  [125 152  66]
#
# Fold 2
# Count X train:  2737
# Count Aspect train:  [1638 1099]
# Count Sentimen train:  [ 997 1214  526]
# Count X validation:  342
# Count Aspect Validation:  [205 137]
# Count Sentimen Validation:  [124 152  66]
# Count X test:  343
# Count Aspect Test:  [205 138]
# Count Sentimen Test:  [125 152  66]
#
# Fold 3
# Count X train:  2738
# Count Aspect train:  [1639 1099]
# Count Sentimen train:  [ 997 1214  527]
# Count X validation:  342
# Count Aspect Validation:  [204 138]
# Count Sentimen Validation:  [124 153  65]
# Count X test:  342
# Count Aspect Test:  [205 137]
# Count Sentimen Test:  [125 151  66]
#
# Fold 4
# Count X train:  2738
# Count Aspect train:  [1638 1100]
# Count Sentimen train:  [ 997 1214  527]
# Count X validation:  342
# Count Aspect Validation:  [205 137]
# Count Sentimen Validation:  [124 152  66]
# Count X test:  342
# Count Aspect Test:  [205 137]
# Count Sentimen Test:  [125 152  65]
#
# Fold 5
# Count X train:  2738
# Count Aspect train:  [1639 1099]
# Count Sentimen train:  [ 997 1215  526]
# Count X validation:  342
# Count Aspect Validation:  [205 137]
# Count Sentimen Validation:  [124 152  66]
# Count X test:  342
# Count Aspect Test:  [204 138]
# Count Sentimen Test:  [125 151  66]

# %% [markdown]
# **CNN**

# %% [markdown]
# ###

# %%
# Multilabel Stratified K-Fold pada data training
mskf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# List untuk menyimpan hasil evaluasi setiap fold
fold_results = []

for fold, (train_idx, test_idx) in enumerate(mskf.split(X_pad, y_multilabel)):
    print(f"Fold {fold + 1}")

    # bagi data training dan test
    X_train, X_test = X_pad[train_idx], X_pad[test_idx] #x
    y_train, y_test = y_multilabel[train_idx], y_multilabel[test_idx] #y

    # buat data testing akhir
    X_validation, X_testing, y_validation, y_testing = train_test_split(X_test, y_test, test_size=0.5, stratify=y_test)

    # Pisahkan y menjadi aspek dan sentimen
    y_train_aspek, y_train_sentimen = y_train[:, :y_aspek.shape[1]], y_train[:, y_aspek.shape[1]:]
    y_validation_aspek, y_validation_sentimen = y_validation[:, :y_aspek.shape[1]], y_validation[:, y_aspek.shape[1]:]
    y_testing_aspek, y_testing_sentimen = y_testing[:, :y_aspek.shape[1]], y_testing[:, y_aspek.shape[1]:]

    # Definisikan model multitask
    input_layer = Input(shape=(max_len,))
    embedding_layer = Embedding(max_words, embedding_dim, input_length=max_len, weights=[embedding_matrix], trainable=False)(input_layer)
    conv1 = Conv1D(128, 5, activation='relu')(embedding_layer)
    pooling1 = MaxPooling1D(2)(conv1)
    dropout1 = Dropout(0.7)(pooling1)
    conv2 = Conv1D(256, 5, activation='relu')(dropout1)
    pooling2 = MaxPooling1D(2)(conv2)
    dropout2 = Dropout(0.7)(pooling2)
    flatten = Flatten()(dropout2)
    dense1 = Dense(64, activation='relu')(flatten)
    dropout3 = Dropout(0.7)(dense1)
    aspek_output = Dense(y_aspek.shape[1], activation='sigmoid', name='aspek_output')(dropout3)
    sentimen_output = Dense(y_sentimen.shape[1], activation='softmax', name='sentimen_output')(dropout3)

    model_multitask = Model(inputs=input_layer, outputs=[aspek_output, sentimen_output])
    model_multitask.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss={'aspek_output': 'binary_crossentropy', 'sentimen_output': 'categorical_crossentropy'},
        metrics={'aspek_output': 'accuracy', 'sentimen_output': 'accuracy'}
    )

    # Train model pada fold ini
    history = model_multitask.fit(
        X_train, {'aspek_output': y_train_aspek, 'sentimen_output': y_train_sentimen},
        validation_data=(X_validation, {'aspek_output': y_validation_aspek, 'sentimen_output': y_validation_sentimen}),
        epochs=30,
        batch_size=64
    )

    # testing
    testing_loss, testing_aspek_loss, testing_sentimen_loss, testing_aspek_acc, testing_sentimen_acc = model_multitask.evaluate(
        X_testing, {'aspek_output': y_testing_aspek, 'sentimen_output': y_testing_sentimen}, verbose=0
    )

    print(f"Fold {fold + 1} -> testing Aspect Acc: {testing_aspek_acc:.4f}, testing Sentiment Acc: {testing_sentimen_acc:.4f}, "
          f"testing Aspect Loss: {testing_aspek_loss:.4f}, testing Sentiment Loss: {testing_sentimen_loss:.4f}")

    # Simpan hasil validasi untuk fold ini
    fold_results.append({
        'testing_aspek_acc': testing_aspek_acc,
        'testing_sentimen_acc': testing_sentimen_acc,
        'testing_aspek_loss': testing_aspek_loss,
        'testing_sentimen_loss': testing_sentimen_loss,
        'history': history.history  # Simpan data history
    })

# Hitung rata-rata hasil evaluasi
mean_aspek_acc = np.mean([result['testing_aspek_acc'] for result in fold_results])
mean_sentimen_acc = np.mean([result['testing_sentimen_acc'] for result in fold_results])
mean_aspek_loss = np.mean([result['testing_aspek_loss'] for result in fold_results])
mean_sentimen_loss = np.mean([result['testing_sentimen_loss'] for result in fold_results])

print("\nRata-rata hasil testing multilabel stratified k-fold:")
print(f"Aspect Accuracy: {mean_aspek_acc:.4f}, Sentiment Accuracy: {mean_sentimen_acc:.4f}")
print(f"Aspect Loss: {mean_aspek_loss:.4f}, Sentiment Loss: {mean_sentimen_loss:.4f}")
# Out:
# Fold 1
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - aspek_output_accuracy: 0.5624 - aspek_output_loss: 0.7088 - loss: 1.7993 - sentimen_output_accuracy: 0.4279 - sentimen_output_loss: 1.0905 - val_aspek_output_accuracy: 0.6023 - val_aspek_output_loss: 0.6785 - val_loss: 1.7306 - val_sentimen_output_accuracy: 0.4912 - val_sentimen_output_loss: 1.0557
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - aspek_output_accuracy: 0.5943 - aspek_output_loss: 0.6771 - loss: 1.7391 - sentimen_output_accuracy: 0.4261 - sentimen_output_loss: 1.0619 - val_aspek_output_accuracy: 0.5994 - val_aspek_output_loss: 0.6653 - val_loss: 1.7119 - val_sentimen_output_accuracy: 0.5000 - val_sentimen_output_loss: 1.0484
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 134ms/step - aspek_output_accuracy: 0.5996 - aspek_output_loss: 0.6671 - loss: 1.6883 - sentimen_output_accuracy: 0.4683 - sentimen_output_loss: 1.0212 - val_aspek_output_accuracy: 0.6404 - val_aspek_output_loss: 0.6465 - val_loss: 1.6244 - val_sentimen_output_accuracy: 0.5994 - val_sentimen_output_loss: 0.9786
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - aspek_output_accuracy: 0.6074 - aspek_output_loss: 0.6606 - loss: 1.6142 - sentimen_output_accuracy: 0.5478 - sentimen_output_loss: 0.9536 - val_aspek_output_accuracy: 0.6813 - val_aspek_output_loss: 0.6224 - val_loss: 1.5258 - val_sentimen_output_accuracy: 0.6257 - val_sentimen_output_loss: 0.9014
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - aspek_output_accuracy: 0.6378 - aspek_output_loss: 0.6398 - loss: 1.5392 - sentimen_output_accuracy: 0.5913 - sentimen_output_loss: 0.8995 - val_aspek_output_accuracy: 0.6637 - val_aspek_output_loss: 0.6075 - val_loss: 1.5016 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.8860
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - aspek_output_accuracy: 0.6452 - aspek_output_loss: 0.6297 - loss: 1.4950 - sentimen_output_accuracy: 0.6037 - sentimen_output_loss: 0.8652 - val_aspek_output_accuracy: 0.6754 - val_aspek_output_loss: 0.5820 - val_loss: 1.3952 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.8071
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - aspek_output_accuracy: 0.6732 - aspek_output_loss: 0.5940 - loss: 1.4327 - sentimen_output_accuracy: 0.6173 - sentimen_output_loss: 0.8387 - val_aspek_output_accuracy: 0.7339 - val_aspek_output_loss: 0.5524 - val_loss: 1.3563 - val_sentimen_output_accuracy: 0.6842 - val_sentimen_output_loss: 0.8003
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - aspek_output_accuracy: 0.7152 - aspek_output_loss: 0.5672 - loss: 1.3933 - sentimen_output_accuracy: 0.6142 - sentimen_output_loss: 0.8261 - val_aspek_output_accuracy: 0.7661 - val_aspek_output_loss: 0.5281 - val_loss: 1.3059 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.7762
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - aspek_output_accuracy: 0.7357 - aspek_output_loss: 0.5428 - loss: 1.3363 - sentimen_output_accuracy: 0.6246 - sentimen_output_loss: 0.7934 - val_aspek_output_accuracy: 0.7953 - val_aspek_output_loss: 0.4861 - val_loss: 1.2328 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.7447
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - aspek_output_accuracy: 0.7528 - aspek_output_loss: 0.5293 - loss: 1.3095 - sentimen_output_accuracy: 0.6337 - sentimen_output_loss: 0.7801 - val_aspek_output_accuracy: 0.8129 - val_aspek_output_loss: 0.4782 - val_loss: 1.2310 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.7515
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - aspek_output_accuracy: 0.7599 - aspek_output_loss: 0.4922 - loss: 1.2728 - sentimen_output_accuracy: 0.6385 - sentimen_output_loss: 0.7805 - val_aspek_output_accuracy: 0.8216 - val_aspek_output_loss: 0.4545 - val_loss: 1.1841 - val_sentimen_output_accuracy: 0.6608 - val_sentimen_output_loss: 0.7312
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - aspek_output_accuracy: 0.7824 - aspek_output_loss: 0.4677 - loss: 1.2299 - sentimen_output_accuracy: 0.6398 - sentimen_output_loss: 0.7621 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.4330 - val_loss: 1.1606 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.7228
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - aspek_output_accuracy: 0.7916 - aspek_output_loss: 0.4493 - loss: 1.2066 - sentimen_output_accuracy: 0.6387 - sentimen_output_loss: 0.7574 - val_aspek_output_accuracy: 0.8333 - val_aspek_output_loss: 0.4136 - val_loss: 1.1310 - val_sentimen_output_accuracy: 0.6784 - val_sentimen_output_loss: 0.7130
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 193ms/step - aspek_output_accuracy: 0.8016 - aspek_output_loss: 0.4434 - loss: 1.1621 - sentimen_output_accuracy: 0.6635 - sentimen_output_loss: 0.7186 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.4034 - val_loss: 1.0946 - val_sentimen_output_accuracy: 0.6784 - val_sentimen_output_loss: 0.6924
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - aspek_output_accuracy: 0.8001 - aspek_output_loss: 0.4334 - loss: 1.1459 - sentimen_output_accuracy: 0.6698 - sentimen_output_loss: 0.7125 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.4048 - val_loss: 1.0939 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.6890
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - aspek_output_accuracy: 0.7988 - aspek_output_loss: 0.4355 - loss: 1.1527 - sentimen_output_accuracy: 0.6492 - sentimen_output_loss: 0.7171 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.3896 - val_loss: 1.0846 - val_sentimen_output_accuracy: 0.6813 - val_sentimen_output_loss: 0.6910
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - aspek_output_accuracy: 0.8082 - aspek_output_loss: 0.3959 - loss: 1.1075 - sentimen_output_accuracy: 0.6619 - sentimen_output_loss: 0.7116 - val_aspek_output_accuracy: 0.8509 - val_aspek_output_loss: 0.3770 - val_loss: 1.0721 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.6905
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - aspek_output_accuracy: 0.8206 - aspek_output_loss: 0.4184 - loss: 1.0820 - sentimen_output_accuracy: 0.6758 - sentimen_output_loss: 0.6635 - val_aspek_output_accuracy: 0.8304 - val_aspek_output_loss: 0.3860 - val_loss: 1.0436 - val_sentimen_output_accuracy: 0.6784 - val_sentimen_output_loss: 0.6627
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 189ms/step - aspek_output_accuracy: 0.8255 - aspek_output_loss: 0.3964 - loss: 1.0526 - sentimen_output_accuracy: 0.6876 - sentimen_output_loss: 0.6562 - val_aspek_output_accuracy: 0.8421 - val_aspek_output_loss: 0.3652 - val_loss: 1.0554 - val_sentimen_output_accuracy: 0.6784 - val_sentimen_output_loss: 0.6821
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - aspek_output_accuracy: 0.8396 - aspek_output_loss: 0.3747 - loss: 1.0290 - sentimen_output_accuracy: 0.6985 - sentimen_output_loss: 0.6543 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.3822 - val_loss: 1.0551 - val_sentimen_output_accuracy: 0.6959 - val_sentimen_output_loss: 0.6649
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - aspek_output_accuracy: 0.8394 - aspek_output_loss: 0.3611 - loss: 1.0128 - sentimen_output_accuracy: 0.6854 - sentimen_output_loss: 0.6518 - val_aspek_output_accuracy: 0.8509 - val_aspek_output_loss: 0.3715 - val_loss: 1.0473 - val_sentimen_output_accuracy: 0.6754 - val_sentimen_output_loss: 0.6740
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - aspek_output_accuracy: 0.8677 - aspek_output_loss: 0.3209 - loss: 0.9439 - sentimen_output_accuracy: 0.6796 - sentimen_output_loss: 0.6230 - val_aspek_output_accuracy: 0.8538 - val_aspek_output_loss: 0.3686 - val_loss: 1.0344 - val_sentimen_output_accuracy: 0.6608 - val_sentimen_output_loss: 0.6641
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - aspek_output_accuracy: 0.8485 - aspek_output_loss: 0.3430 - loss: 0.9620 - sentimen_output_accuracy: 0.7040 - sentimen_output_loss: 0.6191 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3654 - val_loss: 1.0250 - val_sentimen_output_accuracy: 0.7047 - val_sentimen_output_loss: 0.6543
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - aspek_output_accuracy: 0.8437 - aspek_output_loss: 0.3609 - loss: 0.9818 - sentimen_output_accuracy: 0.7135 - sentimen_output_loss: 0.6209 - val_aspek_output_accuracy: 0.8538 - val_aspek_output_loss: 0.3616 - val_loss: 1.0170 - val_sentimen_output_accuracy: 0.7018 - val_sentimen_output_loss: 0.6502
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - aspek_output_accuracy: 0.8523 - aspek_output_loss: 0.3369 - loss: 0.9785 - sentimen_output_accuracy: 0.7068 - sentimen_output_loss: 0.6416 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3743 - val_loss: 1.0309 - val_sentimen_output_accuracy: 0.7076 - val_sentimen_output_loss: 0.6541
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - aspek_output_accuracy: 0.8566 - aspek_output_loss: 0.3294 - loss: 0.9307 - sentimen_output_accuracy: 0.7052 - sentimen_output_loss: 0.6013 - val_aspek_output_accuracy: 0.8596 - val_aspek_output_loss: 0.3682 - val_loss: 1.0317 - val_sentimen_output_accuracy: 0.6988 - val_sentimen_output_loss: 0.6588
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 188ms/step - aspek_output_accuracy: 0.8548 - aspek_output_loss: 0.3373 - loss: 0.9349 - sentimen_output_accuracy: 0.7330 - sentimen_output_loss: 0.5977 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3637 - val_loss: 1.0041 - val_sentimen_output_accuracy: 0.7222 - val_sentimen_output_loss: 0.6462
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - aspek_output_accuracy: 0.8641 - aspek_output_loss: 0.3329 - loss: 0.9485 - sentimen_output_accuracy: 0.7022 - sentimen_output_loss: 0.6156 - val_aspek_output_accuracy: 0.8450 - val_aspek_output_loss: 0.3600 - val_loss: 1.0212 - val_sentimen_output_accuracy: 0.7251 - val_sentimen_output_loss: 0.6598
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 169ms/step - aspek_output_accuracy: 0.8583 - aspek_output_loss: 0.3382 - loss: 0.9274 - sentimen_output_accuracy: 0.7447 - sentimen_output_loss: 0.5892 - val_aspek_output_accuracy: 0.8626 - val_aspek_output_loss: 0.3673 - val_loss: 1.0173 - val_sentimen_output_accuracy: 0.7222 - val_sentimen_output_loss: 0.6518
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - aspek_output_accuracy: 0.8760 - aspek_output_loss: 0.2982 - loss: 0.8775 - sentimen_output_accuracy: 0.7215 - sentimen_output_loss: 0.5793 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3683 - val_loss: 1.0416 - val_sentimen_output_accuracy: 0.6988 - val_sentimen_output_loss: 0.6667
# Fold 1 -> testing Aspect Acc: 0.8222, testing Sentiment Acc: 0.7201, testing Aspect Loss: 0.4087, testing Sentiment Loss: 0.5802
# Fold 2
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - aspek_output_accuracy: 0.5376 - aspek_output_loss: 0.7085 - loss: 1.8219 - sentimen_output_accuracy: 0.3861 - sentimen_output_loss: 1.1134 - val_aspek_output_accuracy: 0.6140 - val_aspek_output_loss: 0.6789 - val_loss: 1.7315 - val_sentimen_output_accuracy: 0.4591 - val_sentimen_output_loss: 1.0521
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - aspek_output_accuracy: 0.5995 - aspek_output_loss: 0.6769 - loss: 1.7242 - sentimen_output_accuracy: 0.4282 - sentimen_output_loss: 1.0473 - val_aspek_output_accuracy: 0.6053 - val_aspek_output_loss: 0.6645 - val_loss: 1.6980 - val_sentimen_output_accuracy: 0.5351 - val_sentimen_output_loss: 1.0329
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - aspek_output_accuracy: 0.6123 - aspek_output_loss: 0.6661 - loss: 1.6890 - sentimen_output_accuracy: 0.5031 - sentimen_output_loss: 1.0229 - val_aspek_output_accuracy: 0.6082 - val_aspek_output_loss: 0.6389 - val_loss: 1.5924 - val_sentimen_output_accuracy: 0.5994 - val_sentimen_output_loss: 0.9559
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - aspek_output_accuracy: 0.6457 - aspek_output_loss: 0.6459 - loss: 1.5741 - sentimen_output_accuracy: 0.5740 - sentimen_output_loss: 0.9281 - val_aspek_output_accuracy: 0.6637 - val_aspek_output_loss: 0.6121 - val_loss: 1.4991 - val_sentimen_output_accuracy: 0.6228 - val_sentimen_output_loss: 0.8874
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - aspek_output_accuracy: 0.6581 - aspek_output_loss: 0.6202 - loss: 1.5328 - sentimen_output_accuracy: 0.5916 - sentimen_output_loss: 0.9126 - val_aspek_output_accuracy: 0.6842 - val_aspek_output_loss: 0.5855 - val_loss: 1.4241 - val_sentimen_output_accuracy: 0.6199 - val_sentimen_output_loss: 0.8396
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 200ms/step - aspek_output_accuracy: 0.6614 - aspek_output_loss: 0.6065 - loss: 1.4651 - sentimen_output_accuracy: 0.6105 - sentimen_output_loss: 0.8586 - val_aspek_output_accuracy: 0.6637 - val_aspek_output_loss: 0.5823 - val_loss: 1.3966 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.8179
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - aspek_output_accuracy: 0.6678 - aspek_output_loss: 0.5992 - loss: 1.4305 - sentimen_output_accuracy: 0.6432 - sentimen_output_loss: 0.8313 - val_aspek_output_accuracy: 0.7047 - val_aspek_output_loss: 0.5574 - val_loss: 1.3467 - val_sentimen_output_accuracy: 0.6374 - val_sentimen_output_loss: 0.7940
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - aspek_output_accuracy: 0.6892 - aspek_output_loss: 0.5812 - loss: 1.4038 - sentimen_output_accuracy: 0.6214 - sentimen_output_loss: 0.8227 - val_aspek_output_accuracy: 0.7427 - val_aspek_output_loss: 0.5677 - val_loss: 1.3808 - val_sentimen_output_accuracy: 0.6433 - val_sentimen_output_loss: 0.8125
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - aspek_output_accuracy: 0.7224 - aspek_output_loss: 0.5560 - loss: 1.3587 - sentimen_output_accuracy: 0.6277 - sentimen_output_loss: 0.8027 - val_aspek_output_accuracy: 0.7719 - val_aspek_output_loss: 0.5072 - val_loss: 1.2812 - val_sentimen_output_accuracy: 0.6462 - val_sentimen_output_loss: 0.7811
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - aspek_output_accuracy: 0.7215 - aspek_output_loss: 0.5378 - loss: 1.3245 - sentimen_output_accuracy: 0.6347 - sentimen_output_loss: 0.7868 - val_aspek_output_accuracy: 0.8129 - val_aspek_output_loss: 0.4718 - val_loss: 1.2414 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.7750
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - aspek_output_accuracy: 0.7873 - aspek_output_loss: 0.4874 - loss: 1.2643 - sentimen_output_accuracy: 0.6282 - sentimen_output_loss: 0.7769 - val_aspek_output_accuracy: 0.8187 - val_aspek_output_loss: 0.4590 - val_loss: 1.2045 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.7523
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - aspek_output_accuracy: 0.7753 - aspek_output_loss: 0.4786 - loss: 1.2169 - sentimen_output_accuracy: 0.6562 - sentimen_output_loss: 0.7383 - val_aspek_output_accuracy: 0.8158 - val_aspek_output_loss: 0.4353 - val_loss: 1.1646 - val_sentimen_output_accuracy: 0.6433 - val_sentimen_output_loss: 0.7331
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - aspek_output_accuracy: 0.7739 - aspek_output_loss: 0.4807 - loss: 1.2359 - sentimen_output_accuracy: 0.6503 - sentimen_output_loss: 0.7551 - val_aspek_output_accuracy: 0.8158 - val_aspek_output_loss: 0.4104 - val_loss: 1.1658 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.7581
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - aspek_output_accuracy: 0.7991 - aspek_output_loss: 0.4552 - loss: 1.1960 - sentimen_output_accuracy: 0.6439 - sentimen_output_loss: 0.7408 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.3889 - val_loss: 1.0893 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.7056
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 134ms/step - aspek_output_accuracy: 0.8023 - aspek_output_loss: 0.4275 - loss: 1.1276 - sentimen_output_accuracy: 0.6616 - sentimen_output_loss: 0.7001 - val_aspek_output_accuracy: 0.8392 - val_aspek_output_loss: 0.3883 - val_loss: 1.1136 - val_sentimen_output_accuracy: 0.6637 - val_sentimen_output_loss: 0.7309
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - aspek_output_accuracy: 0.8079 - aspek_output_loss: 0.4232 - loss: 1.1000 - sentimen_output_accuracy: 0.6785 - sentimen_output_loss: 0.6768 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3745 - val_loss: 1.0737 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.7091
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - aspek_output_accuracy: 0.8135 - aspek_output_loss: 0.4129 - loss: 1.1135 - sentimen_output_accuracy: 0.6785 - sentimen_output_loss: 0.7005 - val_aspek_output_accuracy: 0.8450 - val_aspek_output_loss: 0.3744 - val_loss: 1.0557 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.6929
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - aspek_output_accuracy: 0.8300 - aspek_output_loss: 0.3884 - loss: 1.0578 - sentimen_output_accuracy: 0.6927 - sentimen_output_loss: 0.6695 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3586 - val_loss: 1.0427 - val_sentimen_output_accuracy: 0.6784 - val_sentimen_output_loss: 0.6892
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - aspek_output_accuracy: 0.8430 - aspek_output_loss: 0.3755 - loss: 1.0607 - sentimen_output_accuracy: 0.6712 - sentimen_output_loss: 0.6853 - val_aspek_output_accuracy: 0.8450 - val_aspek_output_loss: 0.3519 - val_loss: 1.0313 - val_sentimen_output_accuracy: 0.6901 - val_sentimen_output_loss: 0.6875
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - aspek_output_accuracy: 0.8240 - aspek_output_loss: 0.4112 - loss: 1.0552 - sentimen_output_accuracy: 0.6971 - sentimen_output_loss: 0.6439 - val_aspek_output_accuracy: 0.8538 - val_aspek_output_loss: 0.3668 - val_loss: 1.0612 - val_sentimen_output_accuracy: 0.6959 - val_sentimen_output_loss: 0.7058
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - aspek_output_accuracy: 0.8337 - aspek_output_loss: 0.3602 - loss: 0.9959 - sentimen_output_accuracy: 0.7005 - sentimen_output_loss: 0.6357 - val_aspek_output_accuracy: 0.8333 - val_aspek_output_loss: 0.3549 - val_loss: 1.0242 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.6783
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - aspek_output_accuracy: 0.8340 - aspek_output_loss: 0.3704 - loss: 1.0029 - sentimen_output_accuracy: 0.7071 - sentimen_output_loss: 0.6325 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.3573 - val_loss: 1.0319 - val_sentimen_output_accuracy: 0.6842 - val_sentimen_output_loss: 0.6790
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 169ms/step - aspek_output_accuracy: 0.8297 - aspek_output_loss: 0.3736 - loss: 0.9935 - sentimen_output_accuracy: 0.7128 - sentimen_output_loss: 0.6199 - val_aspek_output_accuracy: 0.8421 - val_aspek_output_loss: 0.3519 - val_loss: 1.0152 - val_sentimen_output_accuracy: 0.7018 - val_sentimen_output_loss: 0.6697
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - aspek_output_accuracy: 0.8539 - aspek_output_loss: 0.3301 - loss: 0.9360 - sentimen_output_accuracy: 0.7063 - sentimen_output_loss: 0.6058 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3402 - val_loss: 1.0161 - val_sentimen_output_accuracy: 0.7105 - val_sentimen_output_loss: 0.6811
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - aspek_output_accuracy: 0.8671 - aspek_output_loss: 0.3119 - loss: 0.9238 - sentimen_output_accuracy: 0.7231 - sentimen_output_loss: 0.6120 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.3591 - val_loss: 1.0378 - val_sentimen_output_accuracy: 0.7281 - val_sentimen_output_loss: 0.6843
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 18s 322ms/step - aspek_output_accuracy: 0.8309 - aspek_output_loss: 0.3773 - loss: 0.9980 - sentimen_output_accuracy: 0.7250 - sentimen_output_loss: 0.6206 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3401 - val_loss: 1.0089 - val_sentimen_output_accuracy: 0.7135 - val_sentimen_output_loss: 0.6764
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 165ms/step - aspek_output_accuracy: 0.8564 - aspek_output_loss: 0.3357 - loss: 0.9477 - sentimen_output_accuracy: 0.7201 - sentimen_output_loss: 0.6120 - val_aspek_output_accuracy: 0.8596 - val_aspek_output_loss: 0.3283 - val_loss: 1.0019 - val_sentimen_output_accuracy: 0.7281 - val_sentimen_output_loss: 0.6828
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - aspek_output_accuracy: 0.8657 - aspek_output_loss: 0.3137 - loss: 0.8921 - sentimen_output_accuracy: 0.7396 - sentimen_output_loss: 0.5784 - val_aspek_output_accuracy: 0.8333 - val_aspek_output_loss: 0.3365 - val_loss: 1.0109 - val_sentimen_output_accuracy: 0.7164 - val_sentimen_output_loss: 0.6843
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - aspek_output_accuracy: 0.8740 - aspek_output_loss: 0.3071 - loss: 0.8533 - sentimen_output_accuracy: 0.7492 - sentimen_output_loss: 0.5462 - val_aspek_output_accuracy: 0.8450 - val_aspek_output_loss: 0.3350 - val_loss: 1.0012 - val_sentimen_output_accuracy: 0.7135 - val_sentimen_output_loss: 0.6790
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - aspek_output_accuracy: 0.8729 - aspek_output_loss: 0.3022 - loss: 0.8472 - sentimen_output_accuracy: 0.7415 - sentimen_output_loss: 0.5451 - val_aspek_output_accuracy: 0.8626 - val_aspek_output_loss: 0.3333 - val_loss: 1.0131 - val_sentimen_output_accuracy: 0.7135 - val_sentimen_output_loss: 0.6930
# Fold 2 -> testing Aspect Acc: 0.8746, testing Sentiment Acc: 0.6968, testing Aspect Loss: 0.3692, testing Sentiment Loss: 0.6868
# Fold 3
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - aspek_output_accuracy: 0.5389 - aspek_output_loss: 0.7116 - loss: 1.8406 - sentimen_output_accuracy: 0.3713 - sentimen_output_loss: 1.1290 - val_aspek_output_accuracy: 0.6082 - val_aspek_output_loss: 0.6646 - val_loss: 1.7287 - val_sentimen_output_accuracy: 0.4474 - val_sentimen_output_loss: 1.0625
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 142ms/step - aspek_output_accuracy: 0.5873 - aspek_output_loss: 0.6729 - loss: 1.7324 - sentimen_output_accuracy: 0.4440 - sentimen_output_loss: 1.0595 - val_aspek_output_accuracy: 0.5965 - val_aspek_output_loss: 0.6443 - val_loss: 1.6786 - val_sentimen_output_accuracy: 0.4766 - val_sentimen_output_loss: 1.0315
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - aspek_output_accuracy: 0.6128 - aspek_output_loss: 0.6541 - loss: 1.6752 - sentimen_output_accuracy: 0.5038 - sentimen_output_loss: 1.0211 - val_aspek_output_accuracy: 0.6637 - val_aspek_output_loss: 0.6188 - val_loss: 1.5967 - val_sentimen_output_accuracy: 0.5585 - val_sentimen_output_loss: 0.9829
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - aspek_output_accuracy: 0.6558 - aspek_output_loss: 0.6246 - loss: 1.5959 - sentimen_output_accuracy: 0.5513 - sentimen_output_loss: 0.9713 - val_aspek_output_accuracy: 0.6667 - val_aspek_output_loss: 0.6073 - val_loss: 1.5146 - val_sentimen_output_accuracy: 0.5994 - val_sentimen_output_loss: 0.9172
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 140ms/step - aspek_output_accuracy: 0.6718 - aspek_output_loss: 0.6010 - loss: 1.5336 - sentimen_output_accuracy: 0.5694 - sentimen_output_loss: 0.9325 - val_aspek_output_accuracy: 0.6871 - val_aspek_output_loss: 0.5740 - val_loss: 1.4567 - val_sentimen_output_accuracy: 0.5936 - val_sentimen_output_loss: 0.8989
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - aspek_output_accuracy: 0.6815 - aspek_output_loss: 0.5958 - loss: 1.5250 - sentimen_output_accuracy: 0.5727 - sentimen_output_loss: 0.9292 - val_aspek_output_accuracy: 0.7456 - val_aspek_output_loss: 0.5578 - val_loss: 1.3928 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.8506
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - aspek_output_accuracy: 0.7027 - aspek_output_loss: 0.5696 - loss: 1.4503 - sentimen_output_accuracy: 0.5995 - sentimen_output_loss: 0.8806 - val_aspek_output_accuracy: 0.7281 - val_aspek_output_loss: 0.5528 - val_loss: 1.3829 - val_sentimen_output_accuracy: 0.6433 - val_sentimen_output_loss: 0.8418
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - aspek_output_accuracy: 0.7228 - aspek_output_loss: 0.5483 - loss: 1.4027 - sentimen_output_accuracy: 0.6090 - sentimen_output_loss: 0.8543 - val_aspek_output_accuracy: 0.8099 - val_aspek_output_loss: 0.5021 - val_loss: 1.2932 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.8016
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - aspek_output_accuracy: 0.7520 - aspek_output_loss: 0.5042 - loss: 1.3538 - sentimen_output_accuracy: 0.5931 - sentimen_output_loss: 0.8496 - val_aspek_output_accuracy: 0.8158 - val_aspek_output_loss: 0.4759 - val_loss: 1.2167 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.7604
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - aspek_output_accuracy: 0.7630 - aspek_output_loss: 0.5020 - loss: 1.2941 - sentimen_output_accuracy: 0.6359 - sentimen_output_loss: 0.7920 - val_aspek_output_accuracy: 0.8216 - val_aspek_output_loss: 0.4592 - val_loss: 1.1897 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.7492
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 206ms/step - aspek_output_accuracy: 0.7799 - aspek_output_loss: 0.4808 - loss: 1.2569 - sentimen_output_accuracy: 0.6290 - sentimen_output_loss: 0.7760 - val_aspek_output_accuracy: 0.8216 - val_aspek_output_loss: 0.4318 - val_loss: 1.1573 - val_sentimen_output_accuracy: 0.6287 - val_sentimen_output_loss: 0.7462
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - aspek_output_accuracy: 0.7874 - aspek_output_loss: 0.4616 - loss: 1.2531 - sentimen_output_accuracy: 0.6379 - sentimen_output_loss: 0.7914 - val_aspek_output_accuracy: 0.8363 - val_aspek_output_loss: 0.4259 - val_loss: 1.1542 - val_sentimen_output_accuracy: 0.6345 - val_sentimen_output_loss: 0.7420
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - aspek_output_accuracy: 0.8031 - aspek_output_loss: 0.4428 - loss: 1.2041 - sentimen_output_accuracy: 0.6300 - sentimen_output_loss: 0.7614 - val_aspek_output_accuracy: 0.8304 - val_aspek_output_loss: 0.4089 - val_loss: 1.1573 - val_sentimen_output_accuracy: 0.6228 - val_sentimen_output_loss: 0.7649
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - aspek_output_accuracy: 0.8167 - aspek_output_loss: 0.4167 - loss: 1.1856 - sentimen_output_accuracy: 0.6403 - sentimen_output_loss: 0.7688 - val_aspek_output_accuracy: 0.8392 - val_aspek_output_loss: 0.4133 - val_loss: 1.1210 - val_sentimen_output_accuracy: 0.6374 - val_sentimen_output_loss: 0.7245
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - aspek_output_accuracy: 0.8197 - aspek_output_loss: 0.4175 - loss: 1.1252 - sentimen_output_accuracy: 0.6736 - sentimen_output_loss: 0.7077 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.4127 - val_loss: 1.1046 - val_sentimen_output_accuracy: 0.6345 - val_sentimen_output_loss: 0.7119
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 189ms/step - aspek_output_accuracy: 0.8271 - aspek_output_loss: 0.4020 - loss: 1.1189 - sentimen_output_accuracy: 0.6802 - sentimen_output_loss: 0.7169 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3976 - val_loss: 1.0795 - val_sentimen_output_accuracy: 0.6404 - val_sentimen_output_loss: 0.7019
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - aspek_output_accuracy: 0.8267 - aspek_output_loss: 0.4092 - loss: 1.1143 - sentimen_output_accuracy: 0.6729 - sentimen_output_loss: 0.7050 - val_aspek_output_accuracy: 0.8392 - val_aspek_output_loss: 0.4028 - val_loss: 1.0810 - val_sentimen_output_accuracy: 0.6404 - val_sentimen_output_loss: 0.6959
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - aspek_output_accuracy: 0.8369 - aspek_output_loss: 0.3921 - loss: 1.0757 - sentimen_output_accuracy: 0.6810 - sentimen_output_loss: 0.6835 - val_aspek_output_accuracy: 0.8392 - val_aspek_output_loss: 0.3881 - val_loss: 1.0977 - val_sentimen_output_accuracy: 0.6228 - val_sentimen_output_loss: 0.7265
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - aspek_output_accuracy: 0.8419 - aspek_output_loss: 0.3778 - loss: 1.0628 - sentimen_output_accuracy: 0.6771 - sentimen_output_loss: 0.6850 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3832 - val_loss: 1.0563 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.6916
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - aspek_output_accuracy: 0.8457 - aspek_output_loss: 0.3734 - loss: 1.0399 - sentimen_output_accuracy: 0.6642 - sentimen_output_loss: 0.6666 - val_aspek_output_accuracy: 0.8655 - val_aspek_output_loss: 0.3415 - val_loss: 1.0183 - val_sentimen_output_accuracy: 0.6404 - val_sentimen_output_loss: 0.6868
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - aspek_output_accuracy: 0.8388 - aspek_output_loss: 0.3662 - loss: 1.0296 - sentimen_output_accuracy: 0.6815 - sentimen_output_loss: 0.6634 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3745 - val_loss: 1.0401 - val_sentimen_output_accuracy: 0.6287 - val_sentimen_output_loss: 0.6798
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 189ms/step - aspek_output_accuracy: 0.8502 - aspek_output_loss: 0.3455 - loss: 0.9692 - sentimen_output_accuracy: 0.7060 - sentimen_output_loss: 0.6237 - val_aspek_output_accuracy: 0.8626 - val_aspek_output_loss: 0.3640 - val_loss: 1.0286 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.6797
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - aspek_output_accuracy: 0.8563 - aspek_output_loss: 0.3375 - loss: 0.9720 - sentimen_output_accuracy: 0.6914 - sentimen_output_loss: 0.6346 - val_aspek_output_accuracy: 0.8655 - val_aspek_output_loss: 0.3630 - val_loss: 1.0268 - val_sentimen_output_accuracy: 0.6871 - val_sentimen_output_loss: 0.6813
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step - aspek_output_accuracy: 0.8610 - aspek_output_loss: 0.3259 - loss: 0.9536 - sentimen_output_accuracy: 0.6725 - sentimen_output_loss: 0.6277 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3926 - val_loss: 1.0565 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.6813
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 196ms/step - aspek_output_accuracy: 0.8418 - aspek_output_loss: 0.3662 - loss: 0.9845 - sentimen_output_accuracy: 0.7126 - sentimen_output_loss: 0.6183 - val_aspek_output_accuracy: 0.8626 - val_aspek_output_loss: 0.3675 - val_loss: 1.0246 - val_sentimen_output_accuracy: 0.6842 - val_sentimen_output_loss: 0.6750
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - aspek_output_accuracy: 0.8723 - aspek_output_loss: 0.3123 - loss: 0.9177 - sentimen_output_accuracy: 0.7254 - sentimen_output_loss: 0.6053 - val_aspek_output_accuracy: 0.8538 - val_aspek_output_loss: 0.3934 - val_loss: 1.0458 - val_sentimen_output_accuracy: 0.6871 - val_sentimen_output_loss: 0.6696
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 188ms/step - aspek_output_accuracy: 0.8718 - aspek_output_loss: 0.3142 - loss: 0.9294 - sentimen_output_accuracy: 0.7277 - sentimen_output_loss: 0.6153 - val_aspek_output_accuracy: 0.8655 - val_aspek_output_loss: 0.3764 - val_loss: 1.0226 - val_sentimen_output_accuracy: 0.6637 - val_sentimen_output_loss: 0.6668
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - aspek_output_accuracy: 0.8667 - aspek_output_loss: 0.3235 - loss: 0.9424 - sentimen_output_accuracy: 0.7168 - sentimen_output_loss: 0.6189 - val_aspek_output_accuracy: 0.8509 - val_aspek_output_loss: 0.3709 - val_loss: 1.0264 - val_sentimen_output_accuracy: 0.6784 - val_sentimen_output_loss: 0.6744
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - aspek_output_accuracy: 0.8794 - aspek_output_loss: 0.3085 - loss: 0.9098 - sentimen_output_accuracy: 0.7199 - sentimen_output_loss: 0.6013 - val_aspek_output_accuracy: 0.8480 - val_aspek_output_loss: 0.3932 - val_loss: 1.0454 - val_sentimen_output_accuracy: 0.7018 - val_sentimen_output_loss: 0.6771
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 141ms/step - aspek_output_accuracy: 0.8715 - aspek_output_loss: 0.2946 - loss: 0.8617 - sentimen_output_accuracy: 0.7479 - sentimen_output_loss: 0.5672 - val_aspek_output_accuracy: 0.8626 - val_aspek_output_loss: 0.3886 - val_loss: 1.0534 - val_sentimen_output_accuracy: 0.7135 - val_sentimen_output_loss: 0.6922
# Fold 3 -> testing Aspect Acc: 0.8596, testing Sentiment Acc: 0.7251, testing Aspect Loss: 0.3271, testing Sentiment Loss: 0.6732
# Fold 4
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - aspek_output_accuracy: 0.5515 - aspek_output_loss: 0.7107 - loss: 1.8253 - sentimen_output_accuracy: 0.4057 - sentimen_output_loss: 1.1146 - val_aspek_output_accuracy: 0.5994 - val_aspek_output_loss: 0.6811 - val_loss: 1.7500 - val_sentimen_output_accuracy: 0.4357 - val_sentimen_output_loss: 1.0683
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - aspek_output_accuracy: 0.6053 - aspek_output_loss: 0.6759 - loss: 1.7272 - sentimen_output_accuracy: 0.4529 - sentimen_output_loss: 1.0513 - val_aspek_output_accuracy: 0.5994 - val_aspek_output_loss: 0.6725 - val_loss: 1.7328 - val_sentimen_output_accuracy: 0.4678 - val_sentimen_output_loss: 1.0586
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 166ms/step - aspek_output_accuracy: 0.6171 - aspek_output_loss: 0.6643 - loss: 1.7229 - sentimen_output_accuracy: 0.4498 - sentimen_output_loss: 1.0586 - val_aspek_output_accuracy: 0.6199 - val_aspek_output_loss: 0.6426 - val_loss: 1.6393 - val_sentimen_output_accuracy: 0.5351 - val_sentimen_output_loss: 0.9914
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - aspek_output_accuracy: 0.6106 - aspek_output_loss: 0.6547 - loss: 1.6479 - sentimen_output_accuracy: 0.5213 - sentimen_output_loss: 0.9932 - val_aspek_output_accuracy: 0.6813 - val_aspek_output_loss: 0.6347 - val_loss: 1.5665 - val_sentimen_output_accuracy: 0.5819 - val_sentimen_output_loss: 0.9188
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - aspek_output_accuracy: 0.6319 - aspek_output_loss: 0.6405 - loss: 1.5662 - sentimen_output_accuracy: 0.5795 - sentimen_output_loss: 0.9257 - val_aspek_output_accuracy: 0.6871 - val_aspek_output_loss: 0.6112 - val_loss: 1.4896 - val_sentimen_output_accuracy: 0.6170 - val_sentimen_output_loss: 0.8637
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - aspek_output_accuracy: 0.6607 - aspek_output_loss: 0.6129 - loss: 1.4948 - sentimen_output_accuracy: 0.6094 - sentimen_output_loss: 0.8819 - val_aspek_output_accuracy: 0.6813 - val_aspek_output_loss: 0.5854 - val_loss: 1.4451 - val_sentimen_output_accuracy: 0.6082 - val_sentimen_output_loss: 0.8445
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - aspek_output_accuracy: 0.6522 - aspek_output_loss: 0.6108 - loss: 1.4585 - sentimen_output_accuracy: 0.6189 - sentimen_output_loss: 0.8477 - val_aspek_output_accuracy: 0.6930 - val_aspek_output_loss: 0.5521 - val_loss: 1.4060 - val_sentimen_output_accuracy: 0.6082 - val_sentimen_output_loss: 0.8408
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - aspek_output_accuracy: 0.6861 - aspek_output_loss: 0.5867 - loss: 1.4225 - sentimen_output_accuracy: 0.6147 - sentimen_output_loss: 0.8359 - val_aspek_output_accuracy: 0.7105 - val_aspek_output_loss: 0.5308 - val_loss: 1.3389 - val_sentimen_output_accuracy: 0.6287 - val_sentimen_output_loss: 0.7891
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - aspek_output_accuracy: 0.7209 - aspek_output_loss: 0.5579 - loss: 1.3325 - sentimen_output_accuracy: 0.6336 - sentimen_output_loss: 0.7746 - val_aspek_output_accuracy: 0.7719 - val_aspek_output_loss: 0.4993 - val_loss: 1.3003 - val_sentimen_output_accuracy: 0.6345 - val_sentimen_output_loss: 0.7793
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - aspek_output_accuracy: 0.7475 - aspek_output_loss: 0.5240 - loss: 1.2966 - sentimen_output_accuracy: 0.6734 - sentimen_output_loss: 0.7726 - val_aspek_output_accuracy: 0.7865 - val_aspek_output_loss: 0.4828 - val_loss: 1.2667 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.7678
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 185ms/step - aspek_output_accuracy: 0.7736 - aspek_output_loss: 0.4883 - loss: 1.2555 - sentimen_output_accuracy: 0.6482 - sentimen_output_loss: 0.7671 - val_aspek_output_accuracy: 0.7807 - val_aspek_output_loss: 0.4584 - val_loss: 1.2455 - val_sentimen_output_accuracy: 0.6316 - val_sentimen_output_loss: 0.7540
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - aspek_output_accuracy: 0.7749 - aspek_output_loss: 0.4966 - loss: 1.2956 - sentimen_output_accuracy: 0.6340 - sentimen_output_loss: 0.7990 - val_aspek_output_accuracy: 0.7982 - val_aspek_output_loss: 0.4265 - val_loss: 1.2016 - val_sentimen_output_accuracy: 0.6374 - val_sentimen_output_loss: 0.7531
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - aspek_output_accuracy: 0.7842 - aspek_output_loss: 0.4764 - loss: 1.2244 - sentimen_output_accuracy: 0.6666 - sentimen_output_loss: 0.7479 - val_aspek_output_accuracy: 0.7895 - val_aspek_output_loss: 0.4269 - val_loss: 1.1957 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7420
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - aspek_output_accuracy: 0.7962 - aspek_output_loss: 0.4481 - loss: 1.1689 - sentimen_output_accuracy: 0.6779 - sentimen_output_loss: 0.7208 - val_aspek_output_accuracy: 0.8041 - val_aspek_output_loss: 0.4239 - val_loss: 1.1768 - val_sentimen_output_accuracy: 0.6404 - val_sentimen_output_loss: 0.7302
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - aspek_output_accuracy: 0.8151 - aspek_output_loss: 0.4303 - loss: 1.1460 - sentimen_output_accuracy: 0.6731 - sentimen_output_loss: 0.7157 - val_aspek_output_accuracy: 0.8187 - val_aspek_output_loss: 0.4208 - val_loss: 1.1904 - val_sentimen_output_accuracy: 0.6462 - val_sentimen_output_loss: 0.7455
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - aspek_output_accuracy: 0.8002 - aspek_output_loss: 0.4498 - loss: 1.1650 - sentimen_output_accuracy: 0.6608 - sentimen_output_loss: 0.7152 - val_aspek_output_accuracy: 0.8187 - val_aspek_output_loss: 0.3976 - val_loss: 1.1610 - val_sentimen_output_accuracy: 0.6345 - val_sentimen_output_loss: 0.7471
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 195ms/step - aspek_output_accuracy: 0.8216 - aspek_output_loss: 0.3987 - loss: 1.0845 - sentimen_output_accuracy: 0.6791 - sentimen_output_loss: 0.6859 - val_aspek_output_accuracy: 0.8070 - val_aspek_output_loss: 0.4003 - val_loss: 1.1587 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.7268
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - aspek_output_accuracy: 0.8244 - aspek_output_loss: 0.3890 - loss: 1.0568 - sentimen_output_accuracy: 0.6968 - sentimen_output_loss: 0.6678 - val_aspek_output_accuracy: 0.8216 - val_aspek_output_loss: 0.4061 - val_loss: 1.1635 - val_sentimen_output_accuracy: 0.6374 - val_sentimen_output_loss: 0.7352
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - aspek_output_accuracy: 0.8342 - aspek_output_loss: 0.3977 - loss: 1.0378 - sentimen_output_accuracy: 0.7064 - sentimen_output_loss: 0.6400 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.3848 - val_loss: 1.1332 - val_sentimen_output_accuracy: 0.6404 - val_sentimen_output_loss: 0.7170
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - aspek_output_accuracy: 0.8226 - aspek_output_loss: 0.3882 - loss: 1.0223 - sentimen_output_accuracy: 0.7011 - sentimen_output_loss: 0.6341 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.3934 - val_loss: 1.1393 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7266
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - aspek_output_accuracy: 0.8408 - aspek_output_loss: 0.3937 - loss: 1.0232 - sentimen_output_accuracy: 0.6936 - sentimen_output_loss: 0.6296 - val_aspek_output_accuracy: 0.8099 - val_aspek_output_loss: 0.3728 - val_loss: 1.1367 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7297
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - aspek_output_accuracy: 0.8422 - aspek_output_loss: 0.3772 - loss: 0.9916 - sentimen_output_accuracy: 0.7089 - sentimen_output_loss: 0.6144 - val_aspek_output_accuracy: 0.8216 - val_aspek_output_loss: 0.3882 - val_loss: 1.1603 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7482
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 197ms/step - aspek_output_accuracy: 0.8505 - aspek_output_loss: 0.3333 - loss: 0.9477 - sentimen_output_accuracy: 0.6941 - sentimen_output_loss: 0.6145 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.3682 - val_loss: 1.1420 - val_sentimen_output_accuracy: 0.6228 - val_sentimen_output_loss: 0.7318
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - aspek_output_accuracy: 0.8554 - aspek_output_loss: 0.3420 - loss: 0.9036 - sentimen_output_accuracy: 0.7292 - sentimen_output_loss: 0.5617 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.3806 - val_loss: 1.1378 - val_sentimen_output_accuracy: 0.6462 - val_sentimen_output_loss: 0.7365
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - aspek_output_accuracy: 0.8667 - aspek_output_loss: 0.3360 - loss: 0.9472 - sentimen_output_accuracy: 0.7086 - sentimen_output_loss: 0.6112 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.3697 - val_loss: 1.1503 - val_sentimen_output_accuracy: 0.6608 - val_sentimen_output_loss: 0.7357
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 156ms/step - aspek_output_accuracy: 0.8693 - aspek_output_loss: 0.3137 - loss: 0.9111 - sentimen_output_accuracy: 0.7223 - sentimen_output_loss: 0.5974 - val_aspek_output_accuracy: 0.8333 - val_aspek_output_loss: 0.3688 - val_loss: 1.1092 - val_sentimen_output_accuracy: 0.6754 - val_sentimen_output_loss: 0.7124
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - aspek_output_accuracy: 0.8724 - aspek_output_loss: 0.3143 - loss: 0.9018 - sentimen_output_accuracy: 0.7230 - sentimen_output_loss: 0.5875 - val_aspek_output_accuracy: 0.8275 - val_aspek_output_loss: 0.3599 - val_loss: 1.1084 - val_sentimen_output_accuracy: 0.6696 - val_sentimen_output_loss: 0.7103
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - aspek_output_accuracy: 0.8647 - aspek_output_loss: 0.3244 - loss: 0.9004 - sentimen_output_accuracy: 0.7338 - sentimen_output_loss: 0.5760 - val_aspek_output_accuracy: 0.8333 - val_aspek_output_loss: 0.3665 - val_loss: 1.1087 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.7170
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - aspek_output_accuracy: 0.8707 - aspek_output_loss: 0.2976 - loss: 0.8597 - sentimen_output_accuracy: 0.7211 - sentimen_output_loss: 0.5621 - val_aspek_output_accuracy: 0.8304 - val_aspek_output_loss: 0.3760 - val_loss: 1.1293 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.7184
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 245ms/step - aspek_output_accuracy: 0.8632 - aspek_output_loss: 0.3242 - loss: 0.8931 - sentimen_output_accuracy: 0.7388 - sentimen_output_loss: 0.5689 - val_aspek_output_accuracy: 0.8392 - val_aspek_output_loss: 0.3532 - val_loss: 1.1089 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.7336
# Fold 4 -> testing Aspect Acc: 0.8187, testing Sentiment Acc: 0.7018, testing Aspect Loss: 0.4187, testing Sentiment Loss: 0.6645
# Fold 5
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 181ms/step - aspek_output_accuracy: 0.5595 - aspek_output_loss: 0.7046 - loss: 1.8507 - sentimen_output_accuracy: 0.4010 - sentimen_output_loss: 1.1460 - val_aspek_output_accuracy: 0.5965 - val_aspek_output_loss: 0.6738 - val_loss: 1.7157 - val_sentimen_output_accuracy: 0.4942 - val_sentimen_output_loss: 1.0455
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - aspek_output_accuracy: 0.5840 - aspek_output_loss: 0.6779 - loss: 1.7257 - sentimen_output_accuracy: 0.4527 - sentimen_output_loss: 1.0477 - val_aspek_output_accuracy: 0.6316 - val_aspek_output_loss: 0.6574 - val_loss: 1.6652 - val_sentimen_output_accuracy: 0.5439 - val_sentimen_output_loss: 1.0141
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - aspek_output_accuracy: 0.6150 - aspek_output_loss: 0.6600 - loss: 1.6652 - sentimen_output_accuracy: 0.5102 - sentimen_output_loss: 1.0051 - val_aspek_output_accuracy: 0.6579 - val_aspek_output_loss: 0.6388 - val_loss: 1.5645 - val_sentimen_output_accuracy: 0.6228 - val_sentimen_output_loss: 0.9332
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - aspek_output_accuracy: 0.6417 - aspek_output_loss: 0.6429 - loss: 1.5812 - sentimen_output_accuracy: 0.5682 - sentimen_output_loss: 0.9383 - val_aspek_output_accuracy: 0.6608 - val_aspek_output_loss: 0.6249 - val_loss: 1.5004 - val_sentimen_output_accuracy: 0.6550 - val_sentimen_output_loss: 0.8917
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - aspek_output_accuracy: 0.6453 - aspek_output_loss: 0.6444 - loss: 1.5668 - sentimen_output_accuracy: 0.5925 - sentimen_output_loss: 0.9224 - val_aspek_output_accuracy: 0.6842 - val_aspek_output_loss: 0.5981 - val_loss: 1.4431 - val_sentimen_output_accuracy: 0.6520 - val_sentimen_output_loss: 0.8638
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - aspek_output_accuracy: 0.6736 - aspek_output_loss: 0.6090 - loss: 1.4720 - sentimen_output_accuracy: 0.6291 - sentimen_output_loss: 0.8630 - val_aspek_output_accuracy: 0.7135 - val_aspek_output_loss: 0.5600 - val_loss: 1.3626 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.8334
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - aspek_output_accuracy: 0.7034 - aspek_output_loss: 0.5995 - loss: 1.4269 - sentimen_output_accuracy: 0.6314 - sentimen_output_loss: 0.8275 - val_aspek_output_accuracy: 0.7924 - val_aspek_output_loss: 0.5249 - val_loss: 1.3157 - val_sentimen_output_accuracy: 0.6462 - val_sentimen_output_loss: 0.8168
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 194ms/step - aspek_output_accuracy: 0.7473 - aspek_output_loss: 0.5355 - loss: 1.3688 - sentimen_output_accuracy: 0.6262 - sentimen_output_loss: 0.8334 - val_aspek_output_accuracy: 0.8012 - val_aspek_output_loss: 0.4980 - val_loss: 1.2740 - val_sentimen_output_accuracy: 0.6637 - val_sentimen_output_loss: 0.8065
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - aspek_output_accuracy: 0.7429 - aspek_output_loss: 0.5472 - loss: 1.3452 - sentimen_output_accuracy: 0.6289 - sentimen_output_loss: 0.7980 - val_aspek_output_accuracy: 0.8275 - val_aspek_output_loss: 0.4764 - val_loss: 1.2326 - val_sentimen_output_accuracy: 0.6608 - val_sentimen_output_loss: 0.7853
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 168ms/step - aspek_output_accuracy: 0.7626 - aspek_output_loss: 0.5069 - loss: 1.2858 - sentimen_output_accuracy: 0.6391 - sentimen_output_loss: 0.7790 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.4587 - val_loss: 1.1879 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.7649
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - aspek_output_accuracy: 0.7810 - aspek_output_loss: 0.4878 - loss: 1.2630 - sentimen_output_accuracy: 0.6389 - sentimen_output_loss: 0.7752 - val_aspek_output_accuracy: 0.8246 - val_aspek_output_loss: 0.4280 - val_loss: 1.1410 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7475
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 138ms/step - aspek_output_accuracy: 0.7870 - aspek_output_loss: 0.4824 - loss: 1.2135 - sentimen_output_accuracy: 0.6536 - sentimen_output_loss: 0.7311 - val_aspek_output_accuracy: 0.8421 - val_aspek_output_loss: 0.4228 - val_loss: 1.1320 - val_sentimen_output_accuracy: 0.6433 - val_sentimen_output_loss: 0.7388
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - aspek_output_accuracy: 0.7828 - aspek_output_loss: 0.4538 - loss: 1.2121 - sentimen_output_accuracy: 0.6576 - sentimen_output_loss: 0.7583 - val_aspek_output_accuracy: 0.8596 - val_aspek_output_loss: 0.4202 - val_loss: 1.1494 - val_sentimen_output_accuracy: 0.6608 - val_sentimen_output_loss: 0.7640
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 193ms/step - aspek_output_accuracy: 0.8011 - aspek_output_loss: 0.4611 - loss: 1.1941 - sentimen_output_accuracy: 0.6636 - sentimen_output_loss: 0.7329 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3977 - val_loss: 1.1080 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.7434
# Epoch 15/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - aspek_output_accuracy: 0.8016 - aspek_output_loss: 0.4456 - loss: 1.1428 - sentimen_output_accuracy: 0.6768 - sentimen_output_loss: 0.6973 - val_aspek_output_accuracy: 0.8684 - val_aspek_output_loss: 0.3710 - val_loss: 1.1220 - val_sentimen_output_accuracy: 0.6637 - val_sentimen_output_loss: 0.7879
# Epoch 16/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 184ms/step - aspek_output_accuracy: 0.7975 - aspek_output_loss: 0.4454 - loss: 1.1504 - sentimen_output_accuracy: 0.6636 - sentimen_output_loss: 0.7050 - val_aspek_output_accuracy: 0.8450 - val_aspek_output_loss: 0.3956 - val_loss: 1.0847 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.7235
# Epoch 17/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 135ms/step - aspek_output_accuracy: 0.8258 - aspek_output_loss: 0.3934 - loss: 1.0807 - sentimen_output_accuracy: 0.6711 - sentimen_output_loss: 0.6873 - val_aspek_output_accuracy: 0.8772 - val_aspek_output_loss: 0.3574 - val_loss: 1.0611 - val_sentimen_output_accuracy: 0.6550 - val_sentimen_output_loss: 0.7350
# Epoch 18/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - aspek_output_accuracy: 0.8162 - aspek_output_loss: 0.4021 - loss: 1.1013 - sentimen_output_accuracy: 0.6717 - sentimen_output_loss: 0.6992 - val_aspek_output_accuracy: 0.8567 - val_aspek_output_loss: 0.3713 - val_loss: 1.0648 - val_sentimen_output_accuracy: 0.6462 - val_sentimen_output_loss: 0.7346
# Epoch 19/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - aspek_output_accuracy: 0.8312 - aspek_output_loss: 0.4046 - loss: 1.0937 - sentimen_output_accuracy: 0.6884 - sentimen_output_loss: 0.6891 - val_aspek_output_accuracy: 0.8713 - val_aspek_output_loss: 0.3678 - val_loss: 1.0825 - val_sentimen_output_accuracy: 0.6608 - val_sentimen_output_loss: 0.7485
# Epoch 20/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - aspek_output_accuracy: 0.8459 - aspek_output_loss: 0.3699 - loss: 1.0290 - sentimen_output_accuracy: 0.6840 - sentimen_output_loss: 0.6591 - val_aspek_output_accuracy: 0.8684 - val_aspek_output_loss: 0.3577 - val_loss: 1.0638 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7383
# Epoch 21/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - aspek_output_accuracy: 0.8364 - aspek_output_loss: 0.3831 - loss: 1.0136 - sentimen_output_accuracy: 0.6975 - sentimen_output_loss: 0.6306 - val_aspek_output_accuracy: 0.8655 - val_aspek_output_loss: 0.3427 - val_loss: 1.0432 - val_sentimen_output_accuracy: 0.6491 - val_sentimen_output_loss: 0.7274
# Epoch 22/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - aspek_output_accuracy: 0.8485 - aspek_output_loss: 0.3402 - loss: 0.9803 - sentimen_output_accuracy: 0.7053 - sentimen_output_loss: 0.6401 - val_aspek_output_accuracy: 0.8772 - val_aspek_output_loss: 0.3415 - val_loss: 1.0440 - val_sentimen_output_accuracy: 0.6725 - val_sentimen_output_loss: 0.7331
# Epoch 23/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 11s 154ms/step - aspek_output_accuracy: 0.8392 - aspek_output_loss: 0.3696 - loss: 1.0334 - sentimen_output_accuracy: 0.7045 - sentimen_output_loss: 0.6637 - val_aspek_output_accuracy: 0.8743 - val_aspek_output_loss: 0.3407 - val_loss: 1.0337 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.7290
# Epoch 24/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 192ms/step - aspek_output_accuracy: 0.8629 - aspek_output_loss: 0.3516 - loss: 0.9888 - sentimen_output_accuracy: 0.6977 - sentimen_output_loss: 0.6372 - val_aspek_output_accuracy: 0.8684 - val_aspek_output_loss: 0.3363 - val_loss: 1.0481 - val_sentimen_output_accuracy: 0.6637 - val_sentimen_output_loss: 0.7490
# Epoch 25/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 140ms/step - aspek_output_accuracy: 0.8467 - aspek_output_loss: 0.3364 - loss: 0.9686 - sentimen_output_accuracy: 0.6953 - sentimen_output_loss: 0.6322 - val_aspek_output_accuracy: 0.8713 - val_aspek_output_loss: 0.3325 - val_loss: 1.0365 - val_sentimen_output_accuracy: 0.6374 - val_sentimen_output_loss: 0.7251
# Epoch 26/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 191ms/step - aspek_output_accuracy: 0.8586 - aspek_output_loss: 0.3236 - loss: 0.9487 - sentimen_output_accuracy: 0.7140 - sentimen_output_loss: 0.6251 - val_aspek_output_accuracy: 0.8713 - val_aspek_output_loss: 0.3313 - val_loss: 1.0439 - val_sentimen_output_accuracy: 0.6579 - val_sentimen_output_loss: 0.7503
# Epoch 27/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - aspek_output_accuracy: 0.8526 - aspek_output_loss: 0.3251 - loss: 0.9507 - sentimen_output_accuracy: 0.7096 - sentimen_output_loss: 0.6255 - val_aspek_output_accuracy: 0.8772 - val_aspek_output_loss: 0.3387 - val_loss: 1.0447 - val_sentimen_output_accuracy: 0.6813 - val_sentimen_output_loss: 0.7456
# Epoch 28/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 8s 193ms/step - aspek_output_accuracy: 0.8601 - aspek_output_loss: 0.3323 - loss: 0.9364 - sentimen_output_accuracy: 0.7124 - sentimen_output_loss: 0.6042 - val_aspek_output_accuracy: 0.8713 - val_aspek_output_loss: 0.3177 - val_loss: 1.0133 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.7283
# Epoch 29/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - aspek_output_accuracy: 0.8518 - aspek_output_loss: 0.3350 - loss: 0.9175 - sentimen_output_accuracy: 0.7194 - sentimen_output_loss: 0.5825 - val_aspek_output_accuracy: 0.8830 - val_aspek_output_loss: 0.3125 - val_loss: 1.0308 - val_sentimen_output_accuracy: 0.6667 - val_sentimen_output_loss: 0.7443
# Epoch 30/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 12s 168ms/step - aspek_output_accuracy: 0.8763 - aspek_output_loss: 0.3185 - loss: 0.8914 - sentimen_output_accuracy: 0.7426 - sentimen_output_loss: 0.5729 - val_aspek_output_accuracy: 0.8830 - val_aspek_output_loss: 0.3111 - val_loss: 1.0276 - val_sentimen_output_accuracy: 0.6813 - val_sentimen_output_loss: 0.7484
# Fold 5 -> testing Aspect Acc: 0.8450, testing Sentiment Acc: 0.7398, testing Aspect Loss: 0.3504, testing Sentiment Loss: 0.6037
#
# Rata-rata hasil testing multilabel stratified k-fold:
# Aspect Accuracy: 0.8440, Sentiment Accuracy: 0.7167
# Aspect Loss: 0.3748, Sentiment Loss: 0.6417

# %%
# Loop untuk membuat grafik per fold
for fold, result in enumerate(fold_results):
    history = result['history']  # Ambil history dari fold ini
    testing_aspek_acc = result['testing_aspek_acc']
    testing_sentimen_acc = result['testing_sentimen_acc']
    testing_aspek_loss = result['testing_aspek_loss']
    testing_sentimen_loss = result['testing_sentimen_loss']

    # Plot loss
    plt.figure(figsize=(14, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history['aspek_output_loss'], label='Train Loss - Aspect')
    plt.plot(history['val_aspek_output_loss'], label='Val Loss - Aspect')
    plt.axhline(y=testing_aspek_loss, color='m', linestyle='--', label='Testing Loss - Aspect')
    plt.plot(history['sentimen_output_loss'], label='Train Loss - Sentiment')
    plt.plot(history['val_sentimen_output_loss'], label='Val Loss - Sentiment')
    plt.axhline(y=testing_sentimen_loss, color='c', linestyle='--', label='Testing Loss - Sentiment')
    plt.title(f'Fold {fold + 1} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history['aspek_output_accuracy'], label='Train Acc - Aspect')
    plt.plot(history['val_aspek_output_accuracy'], label='Val Acc - Aspect')
    plt.axhline(y=testing_aspek_acc, color='m', linestyle='--', label='Testing Acc - Aspect')
    plt.plot(history['sentimen_output_accuracy'], label='Train Acc - Sentiment')
    plt.plot(history['val_sentimen_output_accuracy'], label='Val Acc - Sentiment')
    plt.axhline(y=testing_sentimen_acc, color='c', linestyle='--', label='Testing Acc - Sentiment')
    plt.title(f'Fold {fold + 1} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# Prediksi untuk semua data testing
pred_aspek, pred_sentimen = model_multitask.predict(X_testing)

# Konversi prediksi menjadi indeks label
pred_aspek_indices = np.argmax(pred_aspek, axis=1)  # Aspek
pred_sentimen_indices = np.argmax(pred_sentimen, axis=1)  # Sentimen

# Konversi label asli menjadi indeks
true_aspek_indices = np.argmax(y_testing_aspek, axis=1)
true_sentimen_indices = np.argmax(y_testing_sentimen, axis=1)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Buat confusion matrix untuk aspek
aspek_cm = confusion_matrix(true_aspek_indices, pred_aspek_indices)

# Tampilkan confusion matrix untuk aspek
aspek_labels = ['ekonomi', 'politik']  # Sesuaikan dengan label aspek Anda
disp_aspek = ConfusionMatrixDisplay(confusion_matrix=aspek_cm, display_labels=aspek_labels)
disp_aspek.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Aspek")
plt.show()

# %%
# Buat confusion matrix untuk sentimen
sentimen_cm = confusion_matrix(true_sentimen_indices, pred_sentimen_indices)

# Tampilkan confusion matrix untuk sentimen
sentimen_labels = ['negatif', 'netral', 'positif']  # Sesuaikan dengan label sentimen Anda
disp_sentimen = ConfusionMatrixDisplay(confusion_matrix=sentimen_cm, display_labels=sentimen_labels)
disp_sentimen.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix - Sentimen")
plt.show()

# %%
# Buat classification report untuk aspek
aspek_labels = ['ekonomi', 'politik']  # Sesuaikan dengan label aspek Anda
aspek_report = classification_report(true_aspek_indices, pred_aspek_indices, target_names=aspek_labels)
print("Classification Report - Aspek")
print(aspek_report)
# Out:
# Classification Report - Aspek
#               precision    recall  f1-score   support
#
#      ekonomi       0.87      0.87      0.87       205
#      politik       0.81      0.80      0.81       137
#
#     accuracy                           0.85       342
#    macro avg       0.84      0.84      0.84       342
# weighted avg       0.84      0.85      0.84       342

# %%
# Buat classification report untuk sentimen
sentimen_labels = ['negatif', 'netral', 'positif']  # Sesuaikan dengan label sentimen Anda
sentimen_report = classification_report(true_sentimen_indices, pred_sentimen_indices, target_names=sentimen_labels)
print("Classification Report - Sentimen")
print(sentimen_report)
# Out:
# Classification Report - Sentimen
#               precision    recall  f1-score   support
#
#      negatif       0.81      0.88      0.84       124
#       netral       0.70      0.79      0.74       152
#      positif       0.69      0.36      0.48        66
#
#     accuracy                           0.74       342
#    macro avg       0.73      0.68      0.69       342
# weighted avg       0.74      0.74      0.73       342
